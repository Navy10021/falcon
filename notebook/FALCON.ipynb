# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/falcon/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/falcon

# %% [markdown]
# ## 1. Run Demo (Full pipeline)

# %%
! python demo.py
# Out:
# ══════════ 🧠 AI Combat Optimization System v2.0 — DEMO ══════════
#
#   Ontology-Driven GNN + RL for Force Minimization
#   학술 연구용 가상 전투 데이터 기반
#
# ═════════════════════════════════════════════════════════════════
#
# ═══════════════════ STEP 1: 전장 온톨로지 & 시나리오 생성 ═══════════════════
#
# ✅ Knowledge Graph 생성 완료:
#    전체 노드: 39개, 엣지: 38개
#    Blue 유닛: 8개 (1140명)
#    Red 유닛:  6개 (586명)
#    Blue 전투력: 3.583
#    Red 전투력:  2.782
#
# ═════════════════ STEP 2: Fog of War (부분 관측 환경) ═════════════════
#
# 📊 Fog Level별 관측 비교:
#    [CLEAR   ] 관측 Red=1개  평균 불확실성=0.357
#    [MODERATE] 관측 Red=2개  평균 불확실성=0.326
#    [MAXIMUM ] 관측 Red=0개  평균 불확실성=0.429
#
# ═══════════ STEP 3: Phase 1 — Bayesian GNN (불확실성 예측) ═══════════
#
# 🔮 MC Dropout GNN 예측 (N=15):
#    예상 사상자: 0.0명 ± 0.1명
#    95% CI: [0.0, 0.3]명
#    위험도: 0.480 ± 0.028
#    Epistemic 불확실성: 0.0077  (모델 불확실성)
#    Aleatoric 불확실성: 0.8975  (데이터 노이즈)
#
#    🎯 행동 권고: HOLD
#    불확실성 매우 높음 → 추가 정찰 후 행동
#    병력 조정 배수: 1.25
#
# ════════════ STEP 4: Phase 2 — Blue vs Red PPO 에이전트 ════════════
#
# 🔵 Blue Agent 행동: Advance
#    log_prob=-1.7868, value estimate=-1.0748
#
# 🔴 Red Agent 행동: Ambush
#    log_prob=-1.7948, value estimate=0.2985
#
# ═══════════════ STEP 5: 전투 시뮬레이션 (Lanchester 엔진) ═══════════════
#
# ⚔️ 에피소드 결과: ONGOING
#    총 20 스텝
#    Blue 누적 사상: 163명
#    Red 누적 사상:  269명
#    최종 Blue 병력: 977명
#    최종 Red 병력:  317명
#
# ══════════ STEP 6: Phase 3 — Human-in-the-Loop (HITL) ══════════
#
# 📋 지휘관 제약 조건 파싱:
#    입력: '가용 병력 800명 이하로, 승률 65% 이상 유지. 포병 지원 선호.'
#    파싱 결과: 최대병력=800, 최소승률=65%, 포병선호=True
#
# ══════════════════════════════════════════════════════════════════════
# 🎯 Pareto 최적 전략 후보안
# ══════════════════════════════════════════════════════════════════════
#
# 📌 [OPTION_4] 최저 사상자
#    투입 병력:     1140명
#    예상 승률:     73.9%
#    예상 사상자:   45명
#    예상 소요시간: 33 스텝
#    위험 수준:     LOW
#    특성:          인명 손실 최소화 우선
#    ⚠️ 제약 위반:  병력 초과: 1140 > 800
#
# 📌 [OPTION_3] 최고 승률
#    투입 병력:     1140명
#    예상 승률:     79.9%
#    예상 사상자:   68명
#    예상 소요시간: 27 스텝
#    위험 수준:     LOW
#    특성:          승률 최우선, 병력 여유 사용
#    ⚠️ 제약 위반:  병력 초과: 1140 > 800
#
# 📌 [OPTION_2] 균형
#    투입 병력:     1104명
#    예상 승률:     71.9%
#    예상 사상자:   88명
#    예상 소요시간: 30 스텝
#    위험 수준:     MEDIUM
#    특성:          병력-성과 균형 최적점
#    ⚠️ 제약 위반:  병력 초과: 1104 > 800
#
# 📌 [OPTION_1] 최소 병력
#    투입 병력:     875명
#    예상 승률:     62.9%
#    예상 사상자:   105명
#    예상 소요시간: 36 스텝
#    위험 수준:     HIGH
#    특성:          병력 절감 최우선, 승률 다소 감수
#    ⚠️ 제약 위반:  병력 초과: 875 > 800, 승률 미달: 62.9% < 65.0%
#
# ══════════════════════════════════════════════════════════════════════
# 📊 지휘관 선호도 분석 (commander_alpha)
#    총 선택 횟수: 1회
#    가장 선호하는 전략: maximum_win_rate (1/1회)
#    AI 추천 채택률: 100.0%
#    병력 절감 선호: 31.4%
#    승률 우선 선호: 36.2%
#    사상자 최소 선호: 32.4%
#
# ══════════════ STEP 7: Explainability — 결정 근거 보고서 ══════════════
#
# 🔍 결정 근거 보고서: blue_3
# ──────────────────────────────────────────────────
# 유닛 유형: armor
# 현재 지형: urban
# 권고 행동: Advance
#
# 주요 판단 근거 (어텐션 가중치):
#   Urban terrain                  ██████████████ (0.710)
#   Enemy artillery                █████████████ (0.680)
#   Low ammo state                 ██████████ (0.540)
#
# 불확실성 분석:
#   Epistemic (모델 불확실성): 0.008
#   Aleatoric (데이터 노이즈): 0.897
#   전체 불확실성 수준: 매우 높음 → 추가 정찰 권고
#
# 사상자 예측:
#   예상: 0.0명 ± 0.1명
#   95% CI: [0.0, 0.3]명
#
# ═════════════ STEP 8: Monte Carlo 강건성 평가 (50 runs) ═════════════
# Monte Carlo 평가: 100% 50/50 [00:04<00:00, 12.28it/s]
#
# ════════════════════════════════════════════════════════════
# 📊 Monte Carlo 강건성 평가 보고서
# ════════════════════════════════════════════════════════════
# 총 실행 횟수: 50회
#
# 🏆 성능 지표:
#   Blue 승률:    4.0% (95% CI: 0.0% ~ 10.0%)
#   평균 사상자:  211.3명 (95% CI: 187.6 ~ 237.2)
#   병력 절감율:  17.4%
#   평균 소요시간: 48.1 스텝
#   전략 강건성:  0.0322
#
# ⚠️ 극단값:
#   최악 사상자:  467명
#   최선 사상자:  59명
#
# 🔍 취약점 분석 (병력 비율별 승률):
# ════════════════════════════════════════════════════════════
#
# ═════════════════════════ 🎯 전체 파이프라인 완료 ═════════════════════════
#
#   온톨로지 → GNN → PPO → HITL → 평가 파이프라인 실행 완료!
#
#   📌 핵심 결과:
#      Blue 승률:     4.0%
#      평균 사상자:    211.3명
#      전략 강건성:    0.0322
#      불확실성(총):   0.9052
#      Pareto 후보:   4개 생성 완료
#
#   🔗 GitHub 배포:
#      README.md → requirements.txt → 각 모듈 → train.py → evaluate.py → demo.py
#
#   ⚠️  본 시스템은 학술 연구용 합성 데이터 기반입니다.
#
# ═════════════════════════════════════════════════════════════════

# %% [markdown]
# ## 2. Ontology Dataset

# %%
! python generate_data.py
# Out:
# ╔══════════════════════════════════════════════╗
# ║  🧠 AI Combat Optimization — 데이터 생성기  ║
# ║  병력 절감을 위한 AI 기술 전장 활용 방안    ║
# ╚══════════════════════════════════════════════╝
#   시나리오: 100개 | 스텝: 20 | IRL 데모: 50/전술 | 시드: 42
#   출력: ./data/
#
#
# [1/4] 전장 시나리오 생성 (100개)...
#   생성 중: 20/100
#   생성 중: 40/100
#   생성 중: 60/100
#   생성 중: 80/100
#   생성 중: 100/100
#   ✅ 시나리오 100개 → data/scenarios.json
#
# [2/4] 시뮬레이션 에피소드 생성 (100개)...
#   롤아웃: 20/100  [Win:11 Loss:7 Draw:2]
#   롤아웃: 40/100  [Win:22 Loss:14 Draw:4]
#   롤아웃: 60/100  [Win:31 Loss:22 Draw:7]
#   롤아웃: 80/100  [Win:43 Loss:30 Draw:7]
#   롤아웃: 100/100  [Win:52 Loss:37 Draw:11]
#   ✅ 에피소드 100개 → data/episodes.json
#      Blue 승률: 52.0%  (Win:52 Loss:37 Draw:11)
#
# [3/4] IRL 전문가 데모 생성...
#   ✅ IRL 데모 250개 (전술 5종)
#      학습 손실: 0.128146
#
# [4/4] 데이터 통계 계산...
#   ✅ 통계 저장 → data/data_stats.json
#
# [+] 온톨로지 통계 시각화 생성...
#   ✅ 시각화 → data/ontology_stats.html
#      브라우저에서 열기: file:///content/drive/MyDrive/falcon/data/ontology_stats.html
#
#   ⏱️  총 소요 시간: 10.8초
#
# ╔══════════════════════════════════════════════╗
# ║     데이터 생성 완료 리포트                  ║
# ╠══════════════════════════════════════════════╣
# ║  📋 시나리오  :  100개 (8개 전술 유형)
# ║  📊 평균 노드 : 38개 노드 / 44개 엣지
# ║  ⚖️  평균 전력비: 1.18 ± 0.53
# ║  🎬 에피소드  :  100개
# ║  🏆 Blue 승률 : 52%  (Win:52 Loss:37 Draw:11)
# ║  📉 병력감소율: 49% 평균
# ║  ⏱️  평균 스텝 : 19.1스텝
# ║  🤖 IRL 데모  :  250개 (5개 전술)
# ╚══════════════════════════════════════════════╝
#
#   📁 생성된 파일:
#     • data/scenarios.json  (757KB)
#     • data/episodes.json  (363KB)
#     • data/irl_demos_summary.json  (958B)
#     • data/data_stats.json  (1KB)
#     • data/ontology_stats.html  (15KB)

# %% [markdown]
# ## 3. Training

# %%
! python train.py --phase 1 --episodes 1000
# Out:
# 🧠 AI Combat Optimization System v2.0
#    Phase 1 | Episodes: 100 | Seed: 42
# ──────────────────────────────────────────────────
# 🔵 Phase 1: Uncertainty-Aware GNN + PPO 훈련 시작
#    총 에피소드: 100
#    Fog 커리큘럼: Enabled
#    MC Dropout 샘플: 10
#   EP    50/100 | Fog=MODERATE | WR=4.0% | R=92.93 | GNN Loss=7.0989
#
# ✅ Phase 1 훈련 완료!
#    최종 Blue 승률: 2.0%

# %%
! python train.py --phase 2 --episodes 5000
# Out:
# 🧠 AI Combat Optimization System v2.0
#    Phase 2 | Episodes: 100 | Seed: 42
# ──────────────────────────────────────────────────
# 🔴 Phase 2: Self-Play (Blue vs Red) 훈련 시작
#
# 🚀 Self-Play 학습 시작 (총 100 에피소드)
# Self-Play:  49% 49/100 [00:24<00:23,  2.16it/s]/content/drive/MyDrive/falcon/rl_agent/blue_agent.py:369: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   value_loss  = F.mse_loss(values_pred.squeeze(), returns_t[batch_idx])
# Self-Play:  50% 50/100 [00:25<00:37,  1.32it/s]
#   EP    50 | Phase=C | Blue WR=8.0% | Avg Cas=207.6 | Force Reduction=17.9% | Nash Gap=0.2716
# Self-Play: 100% 100/100 [00:53<00:00,  1.88it/s]
#
# ✅ 학습 완료!
#    최종 Blue 승률: 6.0%
#    평균 병력 절감율: 17.9%
#    최종 Nash Gap: 0.2716354588414407
#
# 📊 Phase 2 최종 통계:
#    total_episodes: 100
#    blue_win_rate: 0.0600
#    red_win_rate: 0.0000
#    avg_blue_casualties: 208.3500
#    avg_red_casualties: 327.0600
#    avg_force_reduction: 0.1787
#    final_nash_gap: 0.2716
#    converged: False

# %%
! python train.py --phase 3 --episodes 2000 --hitl
# Out:
# usage: train.py [-h] [--phase {1,2}] [--episodes EPISODES] [--lr LR]
#                 [--seed SEED] [--mc-samples MC_SAMPLES]
#                 [--ppo-epochs PPO_EPOCHS] [--log-interval LOG_INTERVAL]
#                 [--save-interval SAVE_INTERVAL]
#                 [--checkpoint-dir CHECKPOINT_DIR]
# train.py: error: argument --phase: invalid choice: '3' (choose from 1, 2)

# %% [markdown]
# ## 4. Evaluation

# %%
! python evaluate.py --monte-carlo 5000
# Out:
# ℹ️ 체크포인트 없음 → 랜덤 초기화 에이전트로 평가
#
# 📊 Monte Carlo 평가 시작 (5000 runs, Fog=MODERATE)
# Monte Carlo 평가:   5% 242/5000 [01:00<28:25,  2.79it/s]Exception ignored in: <generator object tqdm.__iter__ at 0x7990be77cdc0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1265, in close
#     def close(self):
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/falcon/evaluate.py", line 65, in <module>
#     main()
#   File "/content/drive/MyDrive/falcon/evaluate.py", line 49, in main
#     report = evaluator.evaluate(blue_agent, engine, fog_filter=fog_filter, verbose=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/falcon/evaluation/monte_carlo.py", line 99, in evaluate
#     action, _, _ = agent.select_action(state, deterministic=True)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/falcon/rl_agent/blue_agent.py", line 305, in select_action
#     return self.network.get_action(state, deterministic)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/falcon/rl_agent/blue_agent.py", line 183, in get_action
#     logits, value = self(x)
#                     ^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/falcon/rl_agent/blue_agent.py", line 173, in forward
#     value  = self.critic(feat)
#              ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py", line 253, in forward
#     input = module(input)
#             ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py", line 815, in forward
#     return F.gelu(input, approximate=self.approximate)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Monte Carlo 평가:   5% 242/5000 [01:01<20:04,  3.95it/s]

# %%
! python evaluate.py --benchmark historical
# Out:
# usage: evaluate.py [-h] [--checkpoint CHECKPOINT] [--monte-carlo MONTE_CARLO]
#                    [--seed SEED]
#                    [--fog-level {clear,light,moderate,heavy,maximum}]
# evaluate.py: error: unrecognized arguments: --benchmark historical
